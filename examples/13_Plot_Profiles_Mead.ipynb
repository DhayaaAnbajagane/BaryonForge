# %%
import matplotlib.pyplot as plt
import numpy as np

import sys, os; sys.path.insert(0, '../')
import BaryonForge as bfg
import pyccl as ccl
import pandas as pd

#Load cosmology object from CCL. Linear P(k) is needed since we use it for 2-halo term.
#We don't use P(k) anywhere else in this model, so it's ok to use linear P(k) throughout
cosmo = ccl.Cosmology(Omega_c = 0.226, Omega_b = 0.0455, h = 0.7, sigma8 = 0.810, n_s = 0.967, matter_power_spectrum='linear')
h     = cosmo.cosmo.params.h

# %%
#Some plotting configs
plt.rc('text', usetex=True)
plt.rc('font', family='serif', size=22)
plt.rcParams["axes.linewidth"]  = 2.0
plt.rcParams["xtick.major.size"]  = 10
plt.rcParams["xtick.minor.size"]  = 5
plt.rcParams["ytick.major.size"]  = 10
plt.rcParams["ytick.minor.size"]  = 5
plt.rcParams["xtick.direction"]  = "in"
plt.rcParams["ytick.direction"]  = "in"
plt.rcParams["legend.frameon"] = 'False'
plt.rcParams['figure.figsize'] = [10, 10]

# %%
#Load the default params, provided in Table 2 of https://arxiv.org/pdf/2005.00009
bpar = bfg.Profiles.Mead20.Params_TAGN_8p0

#convenience function to give new dictionary with just one param changed
def bpar_new(p, bpar = bpar):
    return {k:v for k,v in bpar.items() if k != p}

#Init the profiles using dictionary of params
DM  = bfg.Profiles.Mead20.DarkMatter(**bpar)
GAS = bfg.Profiles.Mead20.Gas(**bpar)
STR = bfg.Profiles.Mead20.Stars(**bpar)
CLM = bfg.Profiles.Mead20.CollisionlessMatter(**bpar)
DMO = bfg.Profiles.Mead20.DarkMatterOnly(**bpar)
DMB = bfg.Profiles.Mead20.DarkMatterBaryon(**bpar)

#In addition the pressure/temperature defined in Arico++ (which we use blow)
#We also show the numerically integrated profiles, which are obtained by
#using hydrostatic equilibrium alone (as done in https://arxiv.org/abs/2409.03822 for example)
BND = bfg.Profiles.Mead20.Gas(**bpar)
PRS = bfg.Profiles.Pressure(gas = BND, darkmatterbaryon = DMB)
nGS = bfg.Profiles.GasNumberDensity(gas = BND, mean_molecular_weight = 0.59)
TMP = bfg.Profiles.Temperature(pressure = PRS, gasnumberdensity = nGS)

#Pick a mass, in Msun
M = 1e13
a = 1 #scale factor
R200c = ccl.halos.massdef.MassDef200c.get_radius(cosmo, M, a)
R = np.geomspace(0.003 * R200c, 15 * R200c, 1000)
x = R/R200c
mdef = ccl.halos.massdef.MassDef200c

PRS.real(cosmo, R, np.array(M), a)
# Out:
# array([8.90571132e-12, 8.88646198e-12, 8.86720941e-12, 8.84795349e-12,
#        8.82869413e-12, 8.80943163e-12, 8.79016594e-12, 8.77089696e-12,
#        8.75162455e-12, 8.73234866e-12, 8.71306959e-12, 8.69378727e-12,
#        8.67450159e-12, 8.65521240e-12, 8.63591971e-12, 8.61662380e-12,
#        8.59732458e-12, 8.57802192e-12, 8.55871569e-12, 8.53940595e-12,
#        8.52009294e-12, 8.50077656e-12, 8.48145667e-12, 8.46213316e-12,
#        8.44280613e-12, 8.42347579e-12, 8.40414202e-12, 8.38480468e-12,
#        8.36546367e-12, 8.34611915e-12, 8.32677127e-12, 8.30741990e-12,
#        8.28806492e-12, 8.26870622e-12, 8.24934403e-12, 8.22997844e-12,
#        8.21060930e-12, 8.19123652e-12, 8.17185998e-12, 8.15247997e-12,
#        8.13309652e-12, 8.11370948e-12, 8.09431876e-12, 8.07492428e-12,
#        8.05552635e-12, 8.03612493e-12, 8.01671991e-12, 7.99731117e-12,
#        7.97789869e-12, 7.95848276e-12, 7.93906332e-12, 7.91964027e-12,
#        7.90021348e-12, 7.88078297e-12, 7.86134904e-12, 7.84191158e-12,
#        7.82247050e-12, 7.80302568e-12, 7.78357720e-12, 7.76412530e-12,
#        7.74466988e-12, 7.72521085e-12, 7.70574808e-12, 7.68628172e-12,
#        7.66681197e-12, 7.64733871e-12, 7.62786185e-12, 7.60838129e-12,
#        7.58889723e-12, 7.56940980e-12, 7.54991890e-12, 7.53042443e-12,
#        7.51092631e-12, 7.49142479e-12, 7.47191994e-12, 7.45241167e-12,
#        7.43289989e-12, 7.41338454e-12, 7.39386589e-12, 7.37434396e-12,
#        7.35481869e-12, 7.33528998e-12, 7.31575780e-12, 7.29622245e-12,
#        7.27668390e-12, 7.25714208e-12, 7.23759693e-12, 7.21804846e-12,
#        7.19849692e-12, 7.17894230e-12, 7.15938452e-12, 7.13982354e-12,
#        7.12025939e-12, 7.10069232e-12, 7.08112229e-12, 7.06154925e-12,
#        7.04197315e-12, 7.02239408e-12, 7.00281225e-12, 6.98322761e-12,
#        6.96364013e-12, 6.94404977e-12, 6.92445667e-12, 6.90486098e-12,
#        6.88526268e-12, 6.86566174e-12, 6.84605813e-12, 6.82645203e-12,
#        6.80684355e-12, 6.78723267e-12, 6.76761939e-12, 6.74800370e-12,
#        6.72838579e-12, 6.70876573e-12, 6.68914354e-12, 6.66951922e-12,
#        6.64989279e-12, 6.63026443e-12, 6.61063421e-12, 6.59100215e-12,
#        6.57136827e-12, 6.55173262e-12, 6.53209536e-12, 6.51245657e-12,
#        6.49281627e-12, 6.47317451e-12, 6.45353136e-12, 6.43388697e-12,
#        6.41424140e-12, 6.39459472e-12, 6.37494698e-12, 6.35529827e-12,
#        6.33564871e-12, 6.31599839e-12, 6.29634739e-12, 6.27669579e-12,
#        6.25704368e-12, 6.23739117e-12, 6.21773836e-12, 6.19808536e-12,
#        6.17843227e-12, 6.15877918e-12, 6.13912618e-12, 6.11947340e-12,
#        6.09982097e-12, 6.08016902e-12, 6.06051761e-12, 6.04086685e-12,
#        6.02121688e-12, 6.00156787e-12, 5.98191997e-12, 5.96227320e-12,
#        5.94262768e-12, 5.92298360e-12, 5.90334115e-12, 5.88370049e-12,
#        5.86406161e-12, 5.84442465e-12, 5.82478984e-12, 5.80515739e-12,
#        5.78552748e-12, 5.76590004e-12, 5.74627527e-12, 5.72665343e-12,
#        5.70703476e-12, 5.68741941e-12, 5.66780731e-12, 5.64819869e-12,
#        5.62859384e-12, 5.60899306e-12, 5.58939644e-12, 5.56980389e-12,
#        5.55021573e-12, 5.53063227e-12, 5.51105382e-12, 5.49148044e-12,
#        5.47191205e-12, 5.45234900e-12, 5.43279167e-12, 5.41324039e-12,
#        5.39369511e-12, 5.37415582e-12, 5.35462293e-12, 5.33509684e-12,
#        5.31557792e-12, 5.29606598e-12, 5.27656114e-12, 5.25706382e-12,
#        5.23757446e-12, 5.21809346e-12, 5.19862051e-12, 5.17915582e-12,
#        5.15969988e-12, 5.14025314e-12, 5.12081600e-12, 5.10138806e-12,
#        5.08196963e-12, 5.06256125e-12, 5.04316341e-12, 5.02377645e-12,
#        5.00439993e-12, 4.98503426e-12, 4.96568002e-12, 4.94633775e-12,
#        4.92700768e-12, 4.90768936e-12, 4.88838334e-12, 4.86909019e-12,
#        4.84981053e-12, 4.83054443e-12, 4.81129150e-12, 4.79205237e-12,
#        4.77282766e-12, 4.75361801e-12, 4.73442332e-12, 4.71524332e-12,
#        4.69607869e-12, 4.67693011e-12, 4.65779823e-12, 4.63868273e-12,
#        4.61958354e-12, 4.60050137e-12, 4.58143693e-12, 4.56239089e-12,
#        4.54336271e-12, 4.52435252e-12, 4.50536107e-12, 4.48638910e-12,
#        4.46743723e-12, 4.44850479e-12, 4.42959208e-12, 4.41069988e-12,
#        4.39182896e-12, 4.37297986e-12, 4.35415181e-12, 4.33534529e-12,
#        4.31656110e-12, 4.29780003e-12, 4.27906249e-12, 4.26034770e-12,
#        4.24165626e-12, 4.22298901e-12, 4.20434674e-12, 4.18572970e-12,
#        4.16713715e-12, 4.14856981e-12, 4.13002853e-12, 4.11151411e-12,
#        4.09302658e-12, 4.07456533e-12, 4.05613117e-12, 4.03772493e-12,
#        4.01934742e-12, 4.00099840e-12, 3.98267750e-12, 3.96438555e-12,
#        3.94612336e-12, 3.92789174e-12, 3.90969019e-12, 3.89151859e-12,
#        3.87337776e-12, 3.85526851e-12, 3.83719158e-12, 3.81914628e-12,
#        3.80113273e-12, 3.78315173e-12, 3.76520406e-12, 3.74729035e-12,
#        3.72940983e-12, 3.71156280e-12, 3.69375001e-12, 3.67597222e-12,
#        3.65822991e-12, 3.64052231e-12, 3.62284986e-12, 3.60521325e-12,
#        3.58761319e-12, 3.57005000e-12, 3.55252299e-12, 3.53503267e-12,
#        3.51757967e-12, 3.50016463e-12, 3.48278772e-12, 3.46544838e-12,
#        3.44814712e-12, 3.43088453e-12, 3.41366115e-12, 3.39647700e-12,
#        3.37933170e-12, 3.36222575e-12, 3.34515961e-12, 3.32813377e-12,
#        3.31114812e-12, 3.29420247e-12, 3.27729723e-12, 3.26043278e-12,
#        3.24360951e-12, 3.22682725e-12, 3.21008597e-12, 3.19338598e-12,
#        3.17672755e-12, 3.16011095e-12, 3.14353608e-12, 3.12700297e-12,
#        3.11051180e-12, 3.09406276e-12, 3.07765601e-12, 3.06129154e-12,
#        3.04496941e-12, 3.02868966e-12, 3.01245238e-12, 2.99625765e-12,
#        2.98010563e-12, 2.96399628e-12, 2.94792955e-12, 2.93190541e-12,
#        2.91592392e-12, 2.89998537e-12, 2.88408962e-12, 2.86823653e-12,
#        2.85242593e-12, 2.83665793e-12, 2.82093293e-12, 2.80525066e-12,
#        2.78961087e-12, 2.77401329e-12, 2.75845817e-12, 2.74294590e-12,
#        2.72747611e-12, 2.71204843e-12, 2.69666253e-12, 2.68131886e-12,
#        2.66601770e-12, 2.65075861e-12, 2.63554113e-12, 2.62036487e-12,
#        2.60523051e-12, 2.59013818e-12, 2.57508737e-12, 2.56007756e-12,
#        2.54510833e-12, 2.53018060e-12, 2.51529431e-12, 2.50044888e-12,
#        2.48564375e-12, 2.47087857e-12, 2.45615439e-12, 2.44147098e-12,
#        2.42682772e-12, 2.41222403e-12, 2.39765967e-12, 2.38313577e-12,
#        2.36865191e-12, 2.35420749e-12, 2.33980191e-12, 2.32543511e-12,
#        2.31110816e-12, 2.29682056e-12, 2.28257169e-12, 2.26836099e-12,
#        2.25418860e-12, 2.24005545e-12, 2.22596099e-12, 2.21190464e-12,
#        2.19788584e-12, 2.18390500e-12, 2.16996282e-12, 2.15605874e-12,
#        2.14219224e-12, 2.12836281e-12, 2.11457109e-12, 2.10081750e-12,
#        2.08710155e-12, 2.07342277e-12, 2.05978072e-12, 2.04617621e-12,
#        2.03260944e-12, 2.01907997e-12, 2.00558739e-12, 1.99213140e-12,
#        1.97871285e-12, 1.96533177e-12, 1.95198781e-12, 1.93868064e-12,
#        1.92541008e-12, 1.91217695e-12, 1.89898119e-12, 1.88582253e-12,
#        1.87270071e-12, 1.85961569e-12, 1.84656820e-12, 1.83355813e-12,
#        1.82058531e-12, 1.80764954e-12, 1.79475093e-12, 1.78189005e-12,
#        1.76906682e-12, 1.75628113e-12, 1.74353289e-12, 1.73082227e-12,
#        1.71814972e-12, 1.70551521e-12, 1.69291870e-12, 1.68036016e-12,
#        1.66783984e-12, 1.65535805e-12, 1.64291482e-12, 1.63051020e-12,
#        1.61814422e-12, 1.60581715e-12, 1.59352920e-12, 1.58128049e-12,
#        1.56907110e-12, 1.55690116e-12, 1.54477088e-12, 1.53268045e-12,
#        1.52063004e-12, 1.50861980e-12, 1.49664990e-12, 1.48472050e-12,
#        1.47283178e-12, 1.46098397e-12, 1.44917728e-12, 1.43741190e-12,
#        1.42568791e-12, 1.41400555e-12, 1.40236507e-12, 1.39076673e-12,
#        1.37921073e-12, 1.36769709e-12, 1.35622608e-12, 1.34479799e-12,
#        1.33341315e-12, 1.32207170e-12, 1.31077363e-12, 1.29951926e-12,
#        1.28830892e-12, 1.27714295e-12, 1.26602145e-12, 1.25494439e-12,
#        1.24391215e-12, 1.23292507e-12, 1.22198353e-12, 1.21108752e-12,
#        1.20023707e-12, 1.18943256e-12, 1.17867437e-12, 1.16796288e-12,
#        1.15729799e-12, 1.14667977e-12, 1.13610864e-12, 1.12558498e-12,
#        1.11510917e-12, 1.10468100e-12, 1.09430063e-12, 1.08396848e-12,
#        1.07368494e-12, 1.06345036e-12, 1.05326444e-12, 1.04312742e-12,
#        1.03303973e-12, 1.02300176e-12, 1.01301378e-12, 1.00307548e-12,
#        9.93187150e-13, 9.83349202e-13, 9.73562032e-13, 9.63825832e-13,
#        9.54140275e-13, 9.44505705e-13, 9.34922519e-13, 9.25391105e-13,
#        9.15911548e-13, 9.06483559e-13, 8.97107504e-13, 8.87783764e-13,
#        8.78512711e-13, 8.69294310e-13, 8.60128341e-13, 8.51015173e-13,
#        8.41955166e-13, 8.32948671e-13, 8.23995517e-13, 8.15095591e-13,
#        8.06249238e-13, 7.97456797e-13, 7.88718581e-13, 7.80034308e-13,
#        7.71403961e-13, 7.62827860e-13, 7.54306312e-13, 7.45839576e-13,
#        7.37427299e-13, 7.29069540e-13, 7.20766585e-13, 7.12518707e-13,
#        7.04326097e-13, 6.96188370e-13, 6.88105633e-13, 6.80078136e-13,
#        6.72106118e-13, 6.64189688e-13, 6.56328462e-13, 6.48522575e-13,
#        6.40772237e-13, 6.33077647e-13, 6.25438830e-13, 6.17855430e-13,
#        6.10327586e-13, 6.02855467e-13, 5.95439231e-13, 5.88078815e-13,
#        5.80773915e-13, 5.73524654e-13, 5.66331156e-13, 5.59193538e-13,
#        5.52111653e-13, 5.45085263e-13, 5.38114457e-13, 5.31199313e-13,
#        5.24339903e-13, 5.17536014e-13, 5.10787472e-13, 5.04094318e-13,
#        4.97456587e-13, 4.90874298e-13, 4.84347206e-13, 4.77875176e-13,
#        4.71458202e-13, 4.65096270e-13, 4.58789348e-13, 4.52537188e-13,
#        4.46339669e-13, 4.40196735e-13, 4.34108327e-13, 4.28074362e-13,
#        4.22094614e-13, 4.16168951e-13, 4.10297269e-13, 4.04479462e-13,
#        3.98715407e-13, 3.93004911e-13, 3.87347815e-13, 3.81743966e-13,
#        3.76193211e-13, 3.70695404e-13, 3.65250386e-13, 3.59857957e-13,
#        3.54517917e-13, 3.49230066e-13, 3.43994258e-13, 3.38810358e-13,
#        3.33678117e-13, 3.28597286e-13, 3.23567623e-13, 3.18589011e-13,
#        3.13661315e-13, 3.08784234e-13, 3.03957476e-13, 2.99180753e-13,
#        2.94454014e-13, 2.89777092e-13, 2.85149638e-13, 2.80571311e-13,
#        2.76041797e-13, 2.71561125e-13, 2.67129072e-13, 2.62745241e-13,
#        2.58409249e-13, 2.54120768e-13, 2.49879915e-13, 2.45686393e-13,
#        2.41539759e-13, 2.37439588e-13, 2.33385567e-13, 2.29377890e-13,
#        2.25416175e-13, 2.21499935e-13, 2.17628704e-13, 2.13802218e-13,
#        2.10020724e-13, 2.06283753e-13, 2.02590773e-13, 1.98941280e-13,
#        1.95335100e-13, 1.91772498e-13, 1.88252916e-13, 1.84775781e-13,
#        1.81340549e-13, 1.77947193e-13, 1.74595938e-13, 1.71286147e-13,
#        1.68017206e-13, 1.64788533e-13, 1.61600314e-13, 1.58452658e-13,
#        1.55344865e-13, 1.52276281e-13, 1.49246300e-13, 1.46255361e-13,
#        1.43303398e-13, 1.40389662e-13, 1.37513458e-13, 1.34674193e-13,
#        1.31872547e-13, 1.29108261e-13, 1.26380539e-13, 1.23688643e-13,
#        1.21032041e-13, 1.18411625e-13, 1.15826936e-13, 1.13277126e-13,
#        1.10761414e-13, 1.08279393e-13, 1.05832116e-13, 1.03418920e-13,
#        1.01038903e-13, 9.86912392e-14, 9.63757282e-14, 9.40935086e-14,
#        9.18437201e-14, 8.96253997e-14, 8.74376751e-14, 8.52806555e-14,
#        8.31554645e-14, 8.10610526e-14, 7.89963899e-14, 7.69605548e-14,
#        7.49541017e-14, 7.29779973e-14, 7.10310213e-14, 6.91120677e-14,
#        6.72201623e-14, 6.53564831e-14, 6.35216452e-14, 6.17142858e-14,
#        5.99332105e-14, 5.81774379e-14, 5.64488641e-14, 5.47476269e-14,
#        5.30722141e-14, 5.14213258e-14, 4.97940768e-14, 4.81931017e-14,
#        4.66179849e-14, 4.50670215e-14, 4.35387820e-14, 4.20326393e-14,
#        4.05519789e-14, 3.90957195e-14, 3.76618977e-14, 3.62489210e-14,
#        3.48566902e-14, 3.34893322e-14, 3.21449211e-14, 3.08211278e-14,
#        2.95161510e-14, 2.82309073e-14, 2.69701982e-14, 2.57309312e-14,
#        2.45102257e-14, 2.33060104e-14, 2.21212163e-14, 2.09610700e-14,
#        1.98206435e-14, 1.86961452e-14, 1.75851705e-14, 1.64951464e-14,
#        1.54307595e-14, 1.43835163e-14, 1.33478927e-14, 1.23212736e-14,
#        1.13245637e-14, 1.03568257e-14, 9.39890569e-15, 8.44071943e-15,
#        7.47887164e-15, 6.47254216e-15, 5.47722948e-15, 4.56483088e-15,
#        3.77395415e-15, 3.10395400e-15, 2.42574406e-15, 1.84796715e-15,
#        1.44437029e-15, 1.21902703e-15, 1.15246114e-15, 1.12530614e-15,
#        1.10663846e-15, 1.09168764e-15, 1.07600795e-15, 1.05663746e-15,
#        1.03692278e-15, 1.01746096e-15, 9.98249316e-16, 9.79285296e-16,
#        9.60567350e-16, 9.42095670e-16, 9.23867811e-16, 9.05881238e-16,
#        8.88133504e-16, 8.70623443e-16, 8.53350876e-16, 8.36313352e-16,
#        8.19508453e-16, 8.02933843e-16, 7.86588723e-16, 7.70472473e-16,
#        7.54582702e-16, 7.38917102e-16, 7.23473451e-16, 7.08251252e-16,
#        6.93249439e-16, 6.78465725e-16, 6.63897899e-16, 6.49543882e-16,
#        6.35403323e-16, 6.21474820e-16, 6.07756180e-16, 5.94245283e-16,
#        5.80940212e-16, 5.67840624e-16, 5.54944882e-16, 5.42250881e-16,
#        5.29756582e-16, 5.17460234e-16, 5.05361396e-16, 4.93458284e-16,
#        4.81748870e-16, 4.70231186e-16, 4.58903640e-16, 4.47765620e-16,
#        4.36815262e-16, 4.26050606e-16, 4.15469745e-16, 4.05071227e-16,
#        3.94854224e-16, 3.84816846e-16, 3.74957189e-16, 3.65273399e-16,
#        3.55764135e-16, 3.46428335e-16, 3.37264119e-16, 3.28269631e-16,
#        3.19443059e-16, 3.10783140e-16, 3.02288582e-16, 2.93957536e-16,
#        2.85788188e-16, 2.77778763e-16, 2.69928019e-16, 2.62234478e-16,
#        2.54696324e-16, 2.47311776e-16, 2.40079101e-16, 2.32997008e-16,
#        2.26063895e-16, 2.19277978e-16, 2.12637497e-16, 2.06140752e-16,
#        1.99786368e-16, 1.93572665e-16, 1.87497883e-16, 1.81560281e-16,
#        1.75758179e-16, 1.70090096e-16, 1.64554316e-16, 1.59149094e-16,
#        1.53872704e-16, 1.48723469e-16, 1.43699806e-16, 1.38799986e-16,
#        1.34022278e-16, 1.29364966e-16, 1.24826361e-16, 1.20404792e-16,
#        1.16098536e-16, 1.11905873e-16, 1.07825094e-16, 1.03854485e-16,
#        9.99923167e-17, 9.62368772e-17, 9.25864602e-17, 8.90393652e-17,
#        8.55938400e-17, 8.22481330e-17, 7.90005483e-17, 7.58493943e-17,
#        7.27929816e-17, 6.98295192e-17, 6.69572648e-17, 6.41745430e-17,
#        6.14796820e-17, 5.88710047e-17, 5.63466954e-17, 5.39050441e-17,
#        5.15444030e-17, 4.92631270e-17, 4.70595538e-17, 4.49318678e-17,
#        4.28784080e-17, 4.08975626e-17, 3.89877230e-17, 3.71472475e-17,
#        3.53743500e-17, 3.36674314e-17, 3.20249264e-17, 3.04452747e-17,
#        2.89268640e-17, 2.74679695e-17, 2.60670634e-17, 2.47226401e-17,
#        2.34332002e-17, 2.21971735e-17, 2.10129263e-17, 1.98790114e-17,
#        1.87939958e-17, 1.77564552e-17, 1.67648771e-17, 1.58177449e-17,
#        1.49137004e-17, 1.40513968e-17, 1.32294987e-17, 1.24465698e-17,
#        1.17012300e-17, 1.09922186e-17, 1.03182882e-17, 9.67820311e-18,
#        9.07062869e-18, 8.49432739e-18, 7.94814674e-18, 7.43095028e-18,
#        6.94161115e-18, 6.47891979e-18, 6.04178158e-18, 5.62916175e-18,
#        5.24004380e-18, 4.87341785e-18, 4.52821524e-18, 4.20348277e-18,
#        3.89830968e-18, 3.61180516e-18, 3.34308213e-18, 3.09122095e-18,
#        2.85540615e-18, 2.63485362e-18, 2.42880012e-18, 2.23648396e-18,
#        2.05713502e-18, 1.89006962e-18, 1.73462891e-18, 1.59017496e-18,
#        1.45607018e-18, 1.33168771e-18, 1.21646744e-18, 1.10987029e-18,
#        1.01137738e-18, 9.20469867e-19, 8.36652428e-19, 7.59477986e-19,
#        6.88518158e-19, 6.23363125e-19, 5.63603850e-19, 5.08860771e-19,
#        4.58787414e-19, 4.13054017e-19, 3.71346879e-19, 3.33355298e-19,
#        2.98796933e-19, 2.67412233e-19, 2.38955997e-19, 2.13196248e-19,
#        1.89906068e-19, 1.68882228e-19, 1.49937371e-19, 1.32895929e-19,
#        1.17592753e-19, 1.03868845e-19, 9.15831851e-20, 8.06058818e-20,
#        7.08162824e-20, 6.21016099e-20, 5.43552581e-20, 4.74832754e-20,
#        4.13994787e-20, 3.60245751e-20, 3.12849781e-20, 2.71124970e-20,
#        2.34472915e-20, 2.02348453e-20, 1.74255169e-20, 1.49736158e-20,
#        1.28376755e-20, 1.09814229e-20, 9.37211778e-21, 7.98028003e-21,
#        6.77903206e-21, 5.74449639e-21, 4.85584882e-21, 4.09450587e-21,
#        3.44393416e-21, 2.88923364e-21, 2.41743375e-21, 2.01727290e-21,
#        1.67883084e-21, 1.39339280e-21, 1.15321929e-21, 9.51690926e-22,
#        7.83104172e-22, 6.42505149e-22, 5.25600704e-22, 4.28642907e-22,
#        3.48477027e-22, 2.82413317e-22, 2.28151011e-22, 1.83725397e-22,
#        1.47453782e-22, 1.17941138e-22, 9.40136430e-23, 7.46837489e-23,
#        5.91216192e-23, 4.66311709e-23, 3.66439914e-23, 2.86892324e-23,
#        2.23778338e-23, 1.73885813e-23, 1.34579718e-23, 1.03741916e-23,
#        7.96491371e-24, 6.09050100e-24, 4.63787317e-24, 3.51643585e-24,
#        2.65458329e-24, 1.99522775e-24, 1.49308212e-24, 1.11224059e-24,
#        8.24648239e-25, 6.08535500e-25, 4.46933107e-25, 3.26685198e-25,
#        2.37603934e-25, 1.71931711e-25, 1.23773678e-25, 8.86466490e-26,
#        6.31603297e-26, 4.47570056e-26, 3.15401032e-26, 2.21025233e-26,
#        1.54024026e-26, 1.06728668e-26, 7.35170868e-27, 5.03350634e-27,
#        3.42545805e-27, 2.31698361e-27, 1.55757500e-27, 1.04028160e-27,
#        6.90237153e-28, 4.54968230e-28, 2.97912686e-28, 1.93762277e-28,
#        1.25131519e-28, 8.02340548e-29, 5.10780610e-29, 3.22836630e-29,
#        2.02547024e-29, 1.26097362e-29, 7.78944382e-30, 4.77436404e-30,
#        2.90349825e-30, 1.75151081e-30, 1.04770267e-30, 6.21418118e-31,
#        3.65458428e-31, 2.13102036e-31, 1.23162270e-31, 7.05300419e-32,
#        4.00187826e-32, 2.24974753e-32, 1.25304462e-32, 6.91134132e-33,
#        3.77405032e-33, 2.04027617e-33, 1.09192431e-33, 5.78482721e-34,
#        3.03208235e-34, 1.57199712e-34, 8.06136757e-35, 4.08882010e-35,
#        2.05103500e-35, 1.01684733e-35, 4.98166094e-36, 2.41165033e-36,
#        1.15361872e-36, 5.45183951e-37, 2.54360534e-37, 1.17146719e-37,
#        5.32562448e-38, 2.38977615e-38, 1.05821547e-38, 4.62058577e-39])

# %%
fig, ax = plt.subplots(3, 2, figsize = (18, 15), sharex = True, sharey = False)
plt.subplots_adjust(hspace = 0.05, wspace = 0.3)
[a.set_xscale('log') for a in ax.flat]
[a.set_yscale('log') for a in ax.flat]

#Load the default params, provided in Table 2 of https://arxiv.org/pdf/2005.00009
bpar = bfg.Profiles.Mead20.Params_TAGN_8p0

#convenience function to give new dictionary with just one param changed
def bpar_new(p, bpar = bpar):
    return {k:v for k,v in bpar.items() if k != p}

#Init the profiles using dictionary of params
DM  = bfg.Profiles.Mead20.DarkMatter(**bpar)
GAS = bfg.Profiles.Mead20.Gas(**bpar)
STR = bfg.Profiles.Mead20.Stars(**bpar)
CLM = bfg.Profiles.Mead20.CollisionlessMatter(**bpar)
DMO = bfg.Profiles.Mead20.DarkMatterOnly(**bpar)
DMB = bfg.Profiles.Mead20.DarkMatterBaryon(**bpar)

#In addition the pressure/temperature defined in Arico++ (which we use blow)
#We also show the numerically integrated profiles, which are obtained by
#using hydrostatic equilibrium alone (as done in https://arxiv.org/abs/2409.03822 for example)
BND = bfg.Profiles.Mead20.Gas(**bpar)
PRS = bfg.Profiles.Pressure(gas = BND, darkmatterbaryon = DMB)
nGS = bfg.Profiles.GasNumberDensity(gas = BND, mean_molecular_weight = 0.59)
TMP = bfg.Profiles.Temperature(pressure = PRS, gasnumberdensity = nGS)

#Pick a mass, in Msun
M = 1e13
a = 1 #scale factor
R200c = ccl.halos.massdef.MassDef200c.get_radius(cosmo, M, a)
R = np.geomspace(0.003 * R200c, 15 * R200c, 1000)
x = R/R200c
mdef = ccl.halos.massdef.MassDef200c


#First plot fiducial dist
ax.flat[0].plot(x, x**2 * DM.real(cosmo, R, np.array(M), a), lw = 3,  label = 'DM')
ax.flat[0].plot(x, x**2 * GAS.real(cosmo, R, np.array(M), a), lw = 3, label = 'Gas')
ax.flat[0].plot(x, x**2 * STR.real(cosmo, R, np.array(M), a), lw = 3, label = 'Stars')
ax.flat[0].plot(x, x**2 * CLM.real(cosmo, R, np.array(M), a), lw = 3, label = 'CLM')
ax.flat[0].plot(x, x**2 * DMO.real(cosmo, R, np.array(M), a), lw = 3, ls = ':', label = 'DMO')
ax.flat[0].plot(x, x**2 * DMB.real(cosmo, R, np.array(M), a), lw = 3, ls = '--', label = 'DMB')
ax.flat[0].set_ylim(1e10, 4e13)


#Now the gas variations
ax.flat[1].plot(x, x**2 * GAS.real(cosmo, R, np.array(M), a), lw = 3, label = 'Fid')
ax.flat[1].plot(x, x**2 * bfg.Profiles.Mead20.Gas(**bpar_new('Gamma'), Gamma = 2.2).real(cosmo, R, np.array(M), a), lw = 3, label = r'Fid, $2\times\Gamma$')
ax.flat[1].plot(x, x**2 * bfg.Profiles.Mead20.Gas(**bpar_new('beta'),  beta = 0.3).real(cosmo, R, np.array(M), a), lw = 3, label = r'Fid, $0.5\times\beta$')
ax.flat[1].plot(x, x**2 * bfg.Profiles.Mead20.Gas(**bpar_new('eta_b'), eta_b = 0.25).real(cosmo, R, np.array(M), a), lw = 3, label = r'Fid, $0.5\times \eta_b$')
ax.flat[1].set_ylim(9e7, 2e13)

#Now the star variations
ax.flat[2].plot(x, x**2 * STR.real(cosmo, R, np.array(M), a), lw = 3, label = 'Fid')
ax.flat[2].plot(x, x**2 * bfg.Profiles.Mead20.Stars(**bpar_new('M_star'), M_star = 2.2e13/h * 2).real(cosmo, R, np.array(M), a), lw = 3, label = r'Fid, $10 \times M_{1, 0}$')
ax.flat[2].set_ylim(9e7, 2e13)

#Now the TAGN ones variations
ax.flat[3].plot(x, x**2 * bfg.Profiles.Mead20.Gas(**bfg.Profiles.Mead20.Params_TAGN_7p6).real(cosmo, R, np.array(M), a), lw = 3, label = r'$T_{\rm AGN} = 10^7.6 K$')
ax.flat[3].plot(x, x**2 * bfg.Profiles.Mead20.Gas(**bfg.Profiles.Mead20.Params_TAGN_7p8).real(cosmo, R, np.array(M), a), lw = 3, label = r'$T_{\rm AGN} = 10^7.8 K$')
ax.flat[3].plot(x, x**2 * bfg.Profiles.Mead20.Gas(**bfg.Profiles.Mead20.Params_TAGN_8p0).real(cosmo, R, np.array(M), a), lw = 3, label = r'$T_{\rm AGN} = 10^8.0 K$')
ax.flat[3].set_ylim(9e7, 2e13)

#Now the pressure profiles
ax.flat[4].plot(x, x**2 * bfg.Profiles.Mead20.Pressure(**bpar).real(cosmo, R, np.array(M), a), lw = 3, label = 'Fid')
ax.flat[4].plot(x, x**2 * bfg.Profiles.Mead20.Pressure(**bpar_new('Gamma'), Gamma = 2.2).real(cosmo, R, np.array(M), a), lw = 3, label = r'Fid, $2\times\Gamma$')
ax.flat[4].plot(x, x**2 * bfg.Profiles.Mead20.Pressure(**bpar_new('beta'),  beta = 0.3).real(cosmo, R, np.array(M), a), lw = 3, label = r'Fid, $0.5\times\beta$')
ax.flat[4].plot(x, x**2 * bfg.Profiles.Mead20.Pressure(**bpar_new('eta_b'), eta_b = 0.25).real(cosmo, R, np.array(M), a), lw = 3, label = r'Fid, $0.5\times \eta_b$')
ax.flat[4].plot(x, x**2 * PRS.real(cosmo, R, np.array(M), a), lw = 3, label = r'Fid, numerical', color = 'k', ls = '--', alpha = 0.3, zorder = -100)
ax.flat[4].set_ylim(1e-18, 1e-13)

ax.flat[5].plot(x, bfg.Profiles.Mead20.Temperature(**bpar).real(cosmo, R, np.array(M), a), lw = 3, label = 'Fid')
ax.flat[5].plot(x, bfg.Profiles.Mead20.Temperature(**bpar_new('Gamma'), Gamma = 2.2).real(cosmo, R, np.array(M), a), lw = 3, label = r'Fid, $2\times\Gamma$')
ax.flat[5].plot(x, bfg.Profiles.Mead20.Temperature(**bpar_new('beta'),  beta = 0.3).real(cosmo, R, np.array(M), a), lw = 3, label = r'Fid, $0.5\times\beta$')
ax.flat[5].plot(x, bfg.Profiles.Mead20.Temperature(**bpar_new('eta_b'), eta_b = 0.25).real(cosmo, R, np.array(M), a), lw = 3, label = r'Fid, $0.5\times \eta_b$')
ax.flat[5].plot(x, TMP.real(cosmo, R, np.array(M), a), lw = 3, label = r'Fid, numerical', color = 'k', ls = '--', alpha = 0.3, zorder = -100)
ax.flat[5].set_ylim(1e3, 1e8)

ax[0, 0].set_ylabel(r'$(R/R_{\rm 200c})^2\rho$  $[M_\odot/{\rm Mpc}^3]$', size = 20, labelpad = 20)
ax[0, 1].set_ylabel(r'$(R/R_{\rm 200c})^2\rho$  $[M_\odot/{\rm Mpc}^3]$', size = 20, labelpad = 20)
ax[1, 0].set_ylabel(r'$(R/R_{\rm 200c})^2\rho$  $[M_\odot/{\rm Mpc}^3]$', size = 20, labelpad = 20)
ax[1, 1].set_ylabel(r'$(R/R_{\rm 200c})^2\rho$  $[M_\odot/{\rm Mpc}^3]$', size = 20, labelpad = 20)
ax[2, 0].set_ylabel(r'$(R/R_{\rm 200c})^2 P_{\rm gas}$  $[\rm ergs/cm^3]$', size = 20, labelpad = 20)
ax[2, 1].set_ylabel(r'$T_{\rm gas}$  $[\rm K]$', size = 20, labelpad = 20)

ax[2, 0].set_xlabel(r'$R/R_{\rm 200c}$', size = 20)
ax[2, 1].set_xlabel(r'$R/R_{\rm 200c}$', size = 20)

ax[2, 0].tick_params(axis = 'x', pad = 10)
ax[2, 1].tick_params(axis = 'x', pad = 10)
ax[2, 0].text(0.63, 0.3, r'$M_{\rm 200c} = 10^{%d}M_\odot$' % int(np.log10(M)), size = 22,
              color = 'k', alpha = 0.6, ha = 'left', transform = ax[1, 0].transAxes)

[ax.flat[i].legend(fontsize = 20, frameon = False, ncol = 2) for i in range(6)]
ax.flat[3].legend(fontsize = 20, frameon = False, ncol = 1)

plt.show()
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %%
DMO = bfg.Profiles.Mead20.DarkMatterOnly(**bpar)
DMB = bfg.Profiles.Mead20.DarkMatterBaryon(**bpar)

Displacement = bfg.Baryonification3D(DMO, DMB, cosmo, N_int = 50_000)
Displacement.setup_interpolator(N_samples_z = 2, z_min = 0, z_max = 0.01, z_linear_sampling = True, 
                                R_min = 0.001, R_max = 20, N_samples_R = 10000,
                                M_min = 1e12, M_max = 1e16, N_samples_Mass = 5, Rdelta_sampling = True)
# Out:
# Building Table: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:03<00:00,  1.67s/it]

# %%
plt.figure(figsize = (8,6))
plt.xscale('log')
plt.yscale('log')
R = np.geomspace(1e-2, 3, 1000)
a = 1 #scale factor

for M in [1e12, 1e13, 1e14, 1e15]:
    R200c = ccl.halos.massdef.MassDef200c.get_radius(cosmo, M, a)
    c = plt.plot(R, Displacement.displacement(R, M, 1), label = r'$\log_{10}M = %d$' % np.log10(M))
    plt.plot(R, -Displacement.displacement(R, M, 1),color = c[0].get_color(), ls = '--')
    plt.axvline(R200c, color = c[0].get_color(), ls = ':')
    
plt.legend()
plt.xlabel('Radius [Mpc]')
plt.ylabel('Displacement [Mpc]')
plt.show()
